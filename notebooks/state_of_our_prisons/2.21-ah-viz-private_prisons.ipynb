# %% [markdown]
# # Development and testing for private prisons visualization

# %% [markdown]
# ## Script test

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from src.visualization.state_of_our_prisons import private_prisons

# %%
df = private_prisons.test_data()
df
# Out:
#        prison_name provider postal_code   latitude  longitude
# 0        Altcourse   Sodexo      L9 7LH  53.460927  -2.936031
# 1         Ashfield    Serco    BS16 9QJ  51.482420  -2.438869
# 2      Bronzefield   Sodexo    TW15 3JZ  51.432921  -0.482850
# 3        Doncaster    Serco     DN5 8UX  53.525178  -1.145003
# 4         Dovegate    Serco    ST14 8XR  52.872046  -1.783109
# 5       Five Wells      G4S     NN8 2NH  52.297422  -0.697031
# 6      Forest Bank   Sodexo     M27 8FB  53.514251  -2.302093
# 7        Fosse Way    Serco    LE18 4TN  52.582480  -1.143503
# 8   Northumberland   Sodexo    NE65 9XG  55.296086  -1.635300
# 9          Oakwood      G4S    WV10 7QD  52.647955  -2.113013
# 10            Parc      G4S    CF35 6AP  51.530946  -3.563142
# 11    Peterborough   Sodexo     PE3 7PD  52.586514  -0.259961
# 12        Rye Hill      G4S    CV23 8SZ  52.327520  -1.242801
# 13       Thameside    Serco    SE28 0FJ  51.493450   0.087506

# %%
traces = private_prisons.generate_traces(df)
traces
# Out:
# [Scattermap({
#      'hovertemplate': '%{text}',
#      'lat': array([52.297422, 52.647955, 51.530946, 52.32752 ]),
#      'lon': array([-0.697031, -2.113013, -3.563142, -1.242801]),
#      'marker': {'color': '#ef3e42', 'size': 9},
#      'mode': 'markers',
#      'name': 'G4S',
#      'text': array(['Five Wells', 'Oakwood', 'Parc', 'Rye Hill'], dtype=object)
#  }),
#  Scattermap({
#      'hovertemplate': '%{text}',
#      'lat': array([51.48242 , 53.525178, 52.872046, 52.58248 , 51.49345 ]),
#      'lon': array([-2.438869, -1.145003, -1.783109, -1.143503,  0.087506]),
#      'marker': {'color': '#46555f', 'size': 9},
#      'mode': 'markers',
#      'name': 'Serco',
#      'text': array(['Ashfield', 'Doncaster', 'Dovegate', 'Fosse Way', 'Thameside'],
#                    dtype=object)
#  }),
#  Scattermap({
#      'hovertemplate': '%{text}',
#      'lat': array([53.460927, 51.432921, 53.514251, 55.296086, 52.586514]),
# ...

# %%
fig = private_prisons.prepare_chart()
fig

# %%
fig.layout
# Out:
# Layout({
#     'geo': {'fitbounds': 'locations'},
#     'height': 500,
#     'hovermode': 'closest',
#     'legend': {'entrywidth': 40,
#                'itemclick': 'toggleothers',
#                'itemdoubleclick': False,
#                'x': 0.95,
#                'xanchor': 'right',
#                'y': 0.95,
#                'yanchor': 'top'},
#     'map': {'bearing': 0, 'pitch': 10, 'style': 'streets'},
#     'margin': {'l': 0, 'r': 0},
#     'showlegend': True,
#     'template': '...'
# })

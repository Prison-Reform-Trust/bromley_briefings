# %% [markdown]
# # Development and testing for deaths visualization

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from src.visualization.state_of_our_prisons import deaths

# %%
fig = deaths.prepare_chart()
fig

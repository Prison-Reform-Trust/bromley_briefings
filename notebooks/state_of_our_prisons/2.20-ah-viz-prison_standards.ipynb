# %% [markdown]
# # Development and testing for workforce experience visualization

# %% [markdown]
# ## Script test

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from src.visualization.state_of_our_prisons import prison_standards

# %%
df = prison_standards.test_data()
df
# Out:
#     year  percent                        type
# 0   2008       72                      Safety
# 1   2009       78                      Safety
# 2   2010       84                      Safety
# 3   2011       83                      Safety
# 4   2012       80                      Safety
# 5   2013       69                      Safety
# 6   2014       52                      Safety
# 7   2015       56                      Safety
# 8   2016       38                      Safety
# 9   2017       36                      Safety
# 10  2018       37                      Safety
# 11  2019       49                      Safety
# 12  2021       40                      Safety
# 13  2022       51                      Safety
# 14  2023       72                      Safety
# 15  2008       69                     Respect
# 16  2009       76                     Respect
# 17  2010       74                     Respect
# 18  2011       74                     Respect
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   year     60 non-null     int32
#  1   percent  60 non-null     int64
#  2   type     60 non-null     category
# dtypes: category(1), int32(1), int64(1)
# memory usage: 1.1 KB

# %%
prison_standards.prepare_chart()

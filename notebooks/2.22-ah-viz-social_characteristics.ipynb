# %% [markdown]
# # Development and testing for social characteristics visualization

# %% [markdown]
# ## Script test

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from src.visualization.people_in_prison import plotly_social_characteristics

# %%
df = plotly_social_characteristics.test_data()
df
# Out:
#                                        characteristic          group value  \
# 0                         Taken into care as a child     prison_male  24.0
# 1                        Experienced abuse as a child    prison_male  27.0
# 2            Observed violence in the home as a child    prison_male  40.0
# 3        Expelled or permanently excluded from school    prison_male  43.0
# 4         Unemployed in the four weeks before custody    prison_male  67.0
# 5                   Have children under the age of 18    prison_male  45.0
# 6                      Are young fathers (aged 18-20)    prison_male  19.0
# 7               Have symptoms indicative of psychosis    prison_male  15.0
# 8   Identified as suffering from both anxiety and ...    prison_male  23.0
# 9                Have attempted suicide at some point    prison_male  21.0
# 10                        Taken into care as a child   prison_female  31.0
# ...

# %% [markdown]
# ## Development

# %%
import plotly.graph_objects as go
import pandas as pd

# %%
df = plotly_social_characteristics.test_data()

# %%
traces = plotly_social_characteristics.generate_traces(df)
traces
# Out:
# [Scatter({
#      'hovertemplate': '%{x}',
#      'marker': {'color': '#EF553B'},
#      'name': 'prison_male',
#      'orientation': 'h',
#      'text': [prison_male, prison_male, prison_male, prison_male, prison_male,
#               prison_male, prison_male, prison_male, prison_male, prison_male],
#      'textposition': 'top center',
#      'texttemplate': '%{text}%',
#      'x': [24.0, 27.0, 40.0, 43.0, 67.0, 45.0, 19.0, 15.0, 23.0, 21.0],
#      'y': [Taken into care as<br>a child, Experienced abuse<br>as a child, Observed
#            violence<br>in the home as a<br>child, Expelled
#            or<br>permanently<br>excluded from<br>school, Unemployed in the<br>four
#            weeks before<br>custody, Have children<br>under the age of<br>18, Are
#            young fathers<br>(aged 18-20), Have symptoms<br>indicative
#            of<br>psychosis, Identified as<br>suffering from<br>both anxiety
#            and<br>depression, Have attempted<br>suicide at some<br>point]
#  }),
# ...

# %%
fig = plotly_social_characteristics.main()
fig

# %%
df = plotly_social_characteristics.test_data()
df
# Out:
#                                        characteristic  \
# 0                         Taken into care as a child
# 1                        Experienced abuse as a child
# 2            Observed violence in the home as a child
# 3                        Regularly truant from school
# 4        Expelled or permanently excluded from school
# 5                                   No qualifications
# 6         Unemployed in the four weeks before custody
# 7                                     Never had a job
# 8                    Homeless before entering custody
# 9                   Have children under the age of 18
# 10                     Are young fathers (aged 18-20)
# 11              Have symptoms indicative of psychosis
# 12  Identified as suffering from both anxiety and ...
# 13               Have attempted suicide at some point
# 14                        Have ever used Class A drug
# 15  Drank alcohol every day in the four weeks befo...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47 entries, 0 to 46
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   characteristic          47 non-null     category
#  1   group                   47 non-null     category
#  2   value                   47 non-null     object
#  3   wrapped_characteristic  47 non-null     category
# dtypes: category(3), object(1)
# memory usage: 2.2+ KB

# %% [markdown]
# # Development and testing for self-harm visualization

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from src.visualization.state_of_our_prisons import plotly_self_harm

# %%
fig = plotly_self_harm.prepare_chart()
fig

# %% [markdown]
# Note to self: This could be a good opportunity to test out my thinking to include a longer dataset, but restricting the visibility to a certain range now that I have a longer time series.

# %%
fig.layout
# Out:
# Layout({
#     'annotations': [{'font': {'size': 14},
#                      'showarrow': False,
#                      'text': 'Self-harm incidents per 1,000 prisoners',
#                      'x': 0,
#                      'xanchor': 'left',
#                      'xref': 'paper',
#                      'y': 1,
#                      'yanchor': 'bottom',
#                      'yref': 'paper'}],
#     'height': 350,
#     'paper_bgcolor': 'white',
#     'template': '...',
#     'xaxis': {'dtick': 200, 'tickformat': ',.0f', 'ticks': 'inside'},
#     'yaxis': {'automargin': True, 'autorange': 'reversed', 'type': 'category'}
# })

# %% [markdown]
# ## Gender

# %%
from src.visualization.state_of_our_prisons import plotly_self_harm_gender

# %%
fig = plotly_self_harm_gender.prepare_chart()
fig

# %% [markdown]
# # Development and testing for reconviction factors chart

# %% [markdown]
# ## Script test

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from src.visualization.rehabilitation_and_resettlement import reconviction_factors

# %%
fig = reconviction_factors.prepare_chart()
fig

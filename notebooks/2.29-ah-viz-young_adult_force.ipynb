# %% [markdown]
# # Development and testing for child custody and offending chart

# %% [markdown]
# ## Script test

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from src.visualization.people_in_prison import young_adult_force

# %%
fig = young_adult_force.prepare_chart()
fig

# %%
from src.visualization import prt_theme

# %%
annotations = (
    prt_theme
    .add_annotation(
        None,
        prt_theme.wrap_labels("Incidents per 1,000 of the average male prison population to experience force", max_chars=40),
        annotation_type="y-axis", align="left"
    )
)

# %%
annotations
# Out:
# [{'xref': 'paper',
#   'yref': 'paper',
#   'xanchor': 'left',
#   'yanchor': 'bottom',
#   'x': 0,
#   'y': 1,
#   'align': 'left',
#   'showarrow': False,
#   'text': 'Incidents per 1,000 of the average male<br>prison population to experience force',
#   'font_size': 14,
#   'font_color': None}]

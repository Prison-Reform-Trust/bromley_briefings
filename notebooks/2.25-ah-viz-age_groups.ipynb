# %% [markdown]
# # Development and testing for the percentage change in the prison population in England and Wales by age group

# %% [markdown]
# ## Script test

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from src.visualization.people_in_prison import age_groups

# %%
fig = age_groups.prepare_chart()
fig

# %%
y_label = "People in prison (percentage change since 2002)"
len(y_label)
# Out:
# 47

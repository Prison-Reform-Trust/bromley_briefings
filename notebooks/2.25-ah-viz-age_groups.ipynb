# %% [markdown]
# # Development and testing for the percentage change in the prison population in England and Wales by age group

# %% [markdown]
# ## Script test

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from src.visualization.people_in_prison import plotly_age_groups

# %%
fig = plotly_age_groups.prepare_chart()
fig

# %% [markdown]
# # Development and testing for the rates of self-harm amongst women in prison in England and Wales

# %% [markdown]
# ## Script test

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from src.visualization.people_in_prison import plotly_women_self_harm

# %%
fig = plotly_women_self_harm.prepare_chart()
fig

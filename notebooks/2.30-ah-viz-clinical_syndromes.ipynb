# %% [markdown]
# # Development and testing for clinical syndromes chart

# %% [markdown]
# ## Script test

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from src.visualization.health_in_prison import clinical_syndromes

# %%
fig = clinical_syndromes.prepare_chart()
fig

# %% [markdown]
# # Development and testing for remand population visualization

# %% [markdown]
# ## Script test

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from src.visualization.sentencing import plotly_remand_population

# %%
plotly_remand_population.prepare_chart()

# %% [markdown]
# ## Script development

# %%
import os
import chart_studio.plotly as py
import pandas as pd
import plotly.graph_objs as go

# Local modules
import src.utilities as utils
import src.visualization.prt_theme as prt_theme

# Load configuration
config = utils.read_config()

# %%
#Read in datasets
df = pd.read_csv("data/processed/sentencing/remand_population.csv", parse_dates=["date"], date_format="%d-%b-%y")
df
# Out:
#           date  remand_pop
# 0   2010-06-30       13004
# 1   2010-07-31       12611
# 2   2010-08-31       13028
# 3   2010-09-30       12706
# 4   2010-10-31       12755
# ..         ...         ...
# 164 2024-02-29       16340
# 165 2024-03-31       16458
# 166 2024-04-30       16765
# 167 2024-05-31       17050
# 168 2024-06-30       17070
#
# [169 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 109 entries, 0 to 108
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        109 non-null    datetime64[ns]
#  1   remand_pop  109 non-null    int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 1.8 KB

# %%
## Plotting
fig = go.Figure()

fig.add_trace(
    go.Scatter(
        name="Recall population",
        x=df["date"],
        y=df["recall_pop"],
        mode="lines",
        hovertemplate="%{y} prisoners<extra></extra>",
    ),
)
fig.show()

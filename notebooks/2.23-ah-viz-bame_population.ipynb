# %% [markdown]
# # Development and testing for BAME population change visualization

# %% [markdown]
# ## Script test

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from src.visualization.people_in_prison import bame_population

# %%
fig = bame_population.prepare_chart()
fig

# %% [markdown]
# # Development and testing for prison population visualization

# %% [markdown]
# ## Script test

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from src.visualization.sentencing import plotly_prison_population

# %% [markdown]
# ## Script development

# %%
# Importing libraries
import os

import chart_studio
import chart_studio.plotly as py
import pandas as pd
import plotly.graph_objs as go
import plotly.io as pio
from plotly.subplots import make_subplots
from dotenv import find_dotenv, load_dotenv

from src.visualization import prt_theme

##Loading environment variables
dotenv_path = find_dotenv()
load_dotenv(dotenv_path)

##Adding plotly credentials
chart_studio.tools.set_credentials_file(
    username=os.getenv("PLOTLY_USERNAME"), api_key=os.getenv("PLOTLY_API_KEY")
)
#Setting default Plotly template and assigning attributes to prt_template
pio.templates.default = "prt_template"
prt_template = prt_theme.pio.templates['prt_template']

# %%
#Read in datasets
df = pd.read_csv("data/processed/sentencing/prison_population_inc_projections.csv")
df
# Out:
#           date  population  l_projection  c_projection  h_projection
# 0   1990-06-30     44975.0           NaN           NaN           NaN
# 1   1991-06-30     44809.0           NaN           NaN           NaN
# 2   1992-06-30     44719.0           NaN           NaN           NaN
# 3   1993-06-30     44552.0           NaN           NaN           NaN
# 4   1994-06-30     48621.0           NaN           NaN           NaN
# 5   1995-06-30     50962.0           NaN           NaN           NaN
# 6   1996-06-30     55281.0           NaN           NaN           NaN
# 7   1997-06-30     61114.0           NaN           NaN           NaN
# 8   1998-06-30     65298.0           NaN           NaN           NaN
# 9   1999-06-30     64771.0           NaN           NaN           NaN
# 10  2000-06-30     64602.0           NaN           NaN           NaN
# 11  2001-06-30     66301.0           NaN           NaN           NaN
# 12  2002-06-30     70778.0           NaN           NaN           NaN
# 13  2003-06-30     73038.0           NaN           NaN           NaN
# 14  2004-06-30     74657.0           NaN           NaN           NaN
# 15  2005-06-30     75979.0           NaN           NaN           NaN
# 16  2006-06-30     78127.0           NaN           NaN           NaN
# 17  2007-06-30     80216.0           NaN           NaN           NaN
# 18  2008-06-30     82572.0           NaN           NaN           NaN
# 19  2009-06-30     83559.0           NaN           NaN           NaN
# 20  2010-06-30     84725.0           NaN           NaN           NaN
# 21  2011-06-30     85951.0           NaN           NaN           NaN
# 22  2012-06-30     86634.0           NaN           NaN           NaN
# 23  2013-06-30     84249.0           NaN           NaN           NaN
# 24  2014-06-30     85307.0           NaN           NaN           NaN
# 25  2015-06-30     85626.0           NaN           NaN           NaN
# 26  2016-06-30     85348.0           NaN           NaN           NaN
# 27  2017-06-30     85632.0           NaN           NaN           NaN
# 28  2018-06-30     83296.0           NaN           NaN           NaN
# 29  2019-06-30     82710.0           NaN           NaN           NaN
# 30  2020-06-30     79514.0           NaN           NaN           NaN
# 31  2021-06-30     78324.0           NaN           NaN           NaN
# 32  2022-06-30     80659.0           NaN           NaN           NaN
# 33  2023-06-30     85851.0           NaN           NaN           NaN
# 34  2024-09-30     86966.0           NaN       86966.0           NaN
# 35  2025-09-30         NaN       87100.0       89100.0       90300.0
# 36  2026-09-30         NaN       90000.0       93500.0       95200.0
# 37  2027-09-30         NaN       92900.0       97300.0      100000.0
# 38  2028-09-30         NaN       95000.0       99800.0      103800.0

# %%
plotly_prison_population.prepare_chart()

# %% [markdown]
# ## Further testing with Jinja2 template

# %%
from IPython.display import HTML

# %%
HTML('reports/figures/prt_web_template.html')
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="utf-8" />
#     <meta name="viewport" content="width=device-width, initial-scale=1.0" />
# </head>
#
# <body>
#     <hr class="plotly-top">
#     <h2 id="plotly-title">{{ title }}</h2>
#     <h3 id="plotly-subtitle">{{ subtitle }}</h3>
#     {{ fig }}
#     <p id="plotly-source">Source: {{ source }}</p>
#     <hr class="plotly-bottom">
# </body>
# </html>

# %%
IFrame(src='./reports/figures/sentencing/prison_population_inc_projections.html', width=700, height=600)
# Out:
#         <iframe
#             width="700"
#             height="600"
#             src="./reports/figures/sentencing/prison_population_inc_projections.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

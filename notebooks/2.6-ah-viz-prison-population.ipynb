# %% [markdown]
# # Development and testing for prison workforce visualization

# %% [markdown]
# ## Script test

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from src.visualization.sentencing import plotly_prison_population

# %% [markdown]
# ## Script development

# %%
# Importing libraries
import os

import chart_studio
import chart_studio.plotly as py
import pandas as pd
import plotly.graph_objs as go
import plotly.io as pio
from plotly.subplots import make_subplots
from dotenv import find_dotenv, load_dotenv

from src.visualization import prt_theme

##Loading environment variables
dotenv_path = find_dotenv()
load_dotenv(dotenv_path)

##Adding plotly credentials
chart_studio.tools.set_credentials_file(
    username=os.getenv("PLOTLY_USERNAME"), api_key=os.getenv("PLOTLY_API_KEY")
)
#Setting default Plotly template and assigning attributes to prt_template
pio.templates.default = "prt_template"
prt_template = prt_theme.pio.templates['prt_template']

# %%
#Read in datasets
df = pd.read_csv("data/processed/resources_staffing/workforce_staff.csv")

# %%
df['type'].replace({"HMPPS employed prison officers": "HMPPS employed<br>prison officers"}, inplace=True)

# %%
df
# Out:
#     year  percent  number                               type
# 0   2010      0.0   24830  HMPPS employed<br>prison officers
# 1   2011     -2.0   24369  HMPPS employed<br>prison officers
# 2   2012     -8.0   22735  HMPPS employed<br>prison officers
# 3   2013    -13.0   21506  HMPPS employed<br>prison officers
# 4   2014    -26.0   18251  HMPPS employed<br>prison officers
# 5   2015    -27.0   18222  HMPPS employed<br>prison officers
# 6   2016    -26.0   18327  HMPPS employed<br>prison officers
# 7   2017    -26.0   18403  HMPPS employed<br>prison officers
# 8   2018    -15.0   21038  HMPPS employed<br>prison officers
# 9   2019     -9.0   22630  HMPPS employed<br>prison officers
# 10  2020    -12.0   21928  HMPPS employed<br>prison officers
# 11  2021    -12.0   21926  HMPPS employed<br>prison officers
# 12  2022    -11.0   22001  HMPPS employed<br>prison officers
# 13  2023     -7.0   23058  HMPPS employed<br>prison officers
# 14  2010      0.0   85002                  Prison population
# 15  2011      0.4   85374                  Prison population
# 16  2012      1.2   86048                  Prison population
# 17  2013     -1.4   83842                  Prison population
# 18  2014      0.6   85509                  Prison population
# 19  2015      1.4   86193                  Prison population
# 20  2016      0.2   85134                  Prison population
# 21  2017      1.0   85863                  Prison population
# 22  2018     -2.6   82773                  Prison population
# 23  2019     -2.7   82710                  Prison population
# 24  2020     -6.5   79514                  Prison population
# 25  2021     -7.9   78324                  Prison population
# 26  2022     -5.1   80659                  Prison population
# 27  2023     -1.0   85851                  Prison population

# %%
fig = go.Figure()
trace_list= []

for i in df["type"].unique():
    df_type = df[df["type"] == i]

    trace = go.Scatter(
        x=df_type["year"],
        y=df_type["percent"],
        mode="lines+markers",
        text=df_type['type'],
        name=str(df_type['type'].iloc[0]),
        customdata=df_type['number'],
        hovertemplate="<b>Change since 2010:</b> %{y}<br><b>%{text}:</b> %{customdata:,.0f}<extra></extra>"
        )
    
    trace_list.append(trace)

fig.add_traces(trace_list)

fig.show()

# %%
trace_list[0].name
# Out:
# 'HMPPS employed prison officers'

# %%
for j in range(0, len(trace_list)):
    print(trace_list[j].x[-1])
# Out:
# 2023
# 2023

# %% [markdown]
# # Development and testing for sentence explainer charts

# %% [markdown]
# ## Script test

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from src.visualization.sentences_explained import sentences_explained_legend

# %%
df = (
    sentences_explained_legend
    .load_data()
    .pipe(sentences_explained_legend.prepare_data)
    )
df
# Out:
# 0          sentence value                                               text
# 0         suspended    20                                 suspended sentence
# 1         custodial    20                       custodial period of sentence
# 2       licence_dis    20  Part of custodial period spent on licence foll...
# 3      licence_auto    20  Part of custodial period spent on licence foll...
# 4  extended_licence    20                            Extended licence period

# %%
[(i, sentence) for i, sentence in enumerate(df['sentence'])]
# Out:
# [(0, 'suspended'),
#  (1, 'custodial'),
#  (2, 'licence_dis'),
#  (3, 'licence_auto'),
#  (4, 'extended_licence')]

# %%
sentences_explained_legend.generate_traces(df)
# Out:
# [Bar({
#      'customdata': [Suspended sentence],
#      'hovertemplate': '%{customdata}<extra></extra>',
#      'insidetextanchor': 'middle',
#      'marker': {'color': '#F9A237'},
#      'orientation': 'h',
#      'text': 'Suspended<br>sentence',
#      'textfont': {'color': 'white', 'size': 14},
#      'textposition': 'inside',
#      'width': 7,
#      'x': [20],
#      'y': [1]
#  }),
#  Bar({
#      'customdata': [Custodial period of<br>sentence],
#      'hovertemplate': '%{customdata}<extra></extra>',
#      'insidetextanchor': 'middle',
#      'marker': {'color': '#A01D28'},
#      'orientation': 'h',
#      'text': 'Custodial period<br>of sentence',
#      'textfont': {'color': 'white', 'size': 14},
#      'textposition': 'inside',
#      'width': 7,
#      'x': [20],
#      'y': [1]
#  }),
#  Bar({
#      'customdata': [Part of custodial period<br>spent on licence<br>following
#                     discretionary<br>release],
# ...

# %%
fig = sentences_explained_legend.prepare_chart()
fig

# %% [markdown]
# ## Suspended sentence

# %%
from src.visualization.sentences_explained import suspended_sentence

# %%
fig = suspended_sentence.prepare_chart()
fig

# %% [markdown]
# ## SDS less serious

# %%
from src.visualization.sentences_explained import SDS_less_serious

# %%
fig = SDS_less_serious.prepare_chart()
fig

# %% [markdown]
# ## SDS more serious

# %%
from src.visualization.sentences_explained import SDS_more_serious

# %%
fig = SDS_more_serious.prepare_chart()
fig

# %% [markdown]
# ## SDS terrorism

# %%
from src.visualization.sentences_explained import SDS_terrorism

# %%
fig = SDS_terrorism.prepare_chart()
fig

# %% [markdown]
# ## SOPC

# %%
from src.visualization.sentences_explained import SOPC

# %%
fig = SOPC.prepare_chart()
fig

# %% [markdown]
# ## EDS

# %%
from src.visualization.sentences_explained import EDS

# %%
fig = EDS.prepare_chart()
fig

# %% [markdown]
# ## EDS terrorism

# %%
from src.visualization.sentences_explained import EDS_terrorism

# %%
fig = EDS_terrorism.prepare_chart()
fig

# %% [markdown]
# ## STS

# %%
from src.visualization.sentences_explained import STS

# %%
fig = STS.prepare_chart()
fig

# %% [markdown]
# ## IPP

# %%
from src.visualization.sentences_explained import IPP

# %%
fig = IPP.prepare_chart()
fig

# %% [markdown]
# ## Life sentence

# %%
from src.visualization.sentences_explained import life_sentence

# %%
fig = life_sentence.prepare_chart()
fig

# %% [markdown]
# # Development and testing for the proportion of receptions by offence and sentence length, by sex

# %% [markdown]
# ## Script test

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from src.visualization.people_in_prison import offences_sentences_by_sex

# %%
fig = offences_sentences_by_sex.prepare_chart()
fig

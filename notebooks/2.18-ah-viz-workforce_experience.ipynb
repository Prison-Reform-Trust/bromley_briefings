# %% [markdown]
# # Development and testing for workforce experience visualization

# %% [markdown]
# ## Script test

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from src.visualization.state_of_our_prisons import plotly_workforce_experience

# %%
df = plotly_workforce_experience.main()
df
# Out:
#     year  short  long  middle
# 0   2010     13    56      31
# 1   2011     10    56      34
# 2   2012      4    57      39
# 3   2013      4    62      34
# 4   2014      2    66      32
# 5   2015      8    65      27
# 6   2016     16    63      21
# 7   2017     24    61      15
# 8   2018     36    51      13
# 9   2019     42    46      12
# 10  2020     40    44      16
# 11  2021     32    41      27
# 12  2022     29    37      34
# 13  2023     36    31      33
# 14  2024     42    26      32

# %%
fig = plotly_workforce_experience.create_chart(df)
fig

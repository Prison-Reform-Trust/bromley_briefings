# %% [markdown]
# # Development and testing for deaths visualization

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from src.visualization.state_of_our_prisons import plotly_deaths

# %%
df = plotly_deaths.main()
df
# Out:
#                         ids      death_type  value          parent
# 0              Total deaths    Total deaths    291             NaN
# 1            Self-inflicted  Self-inflicted     85    Total deaths
# 2     Self-inflicted - Male            Male     82  Self-inflicted
# 3   Self-inflicted - Female          Female      3  Self-inflicted
# 4            Natural causes  Natural causes    171    Total deaths
# 5     Natural causes - Male            Male    168  Natural causes
# 6   Natural causes - Female          Female      3  Natural causes
# 7                  Homicide        Homicide      1    Total deaths
# 8           Homicide - Male            Male      1        Homicide
# 9         Homicide - Female          Female      0        Homicide
# 10                    Other           Other     34    Total deaths
# 11             Other - Male            Male     31           Other
# 12           Other - Female          Female      3           Other

# %%
fig = plotly_deaths.create_chart(df)
fig

# %%
fig.data
# Out:
# (Sunburst({
#      'branchvalues': 'total',
#      'hovertemplate': ('<b>%{label}</b><br>%{value} de' ... '%} of %{parent}<extra></extra>'),
#      'ids': array(['Total deaths', 'Self-inflicted', 'Self-inflicted - Male',
#                    'Self-inflicted - Female', 'Natural causes', 'Natural causes - Male',
#                    'Natural causes - Female', 'Homicide', 'Homicide - Male',
#                    'Homicide - Female', 'Other', 'Other - Male', 'Other - Female'],
#                   dtype=object),
#      'insidetextorientation': 'horizontal',
#      'labels': array(['Total deaths', 'Self-inflicted', 'Male', 'Female', 'Natural causes',
#                       'Male', 'Female', 'Homicide', 'Male', 'Female', 'Other', 'Male',
#                       'Female'], dtype=object),
#      'marker': {'line': {'color': '#F7F2F2'}},
#      'parents': array(['nan', 'Total deaths', 'Self-inflicted', 'Self-inflicted',
# ...

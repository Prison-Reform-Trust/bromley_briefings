# %% [markdown]
# # Development and testing for imprisonment rates visualization

# %% [markdown]
# ## Script test

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from src.visualization.sentencing import sentenced_receptions

# %%
sentenced_receptions.create_chart()

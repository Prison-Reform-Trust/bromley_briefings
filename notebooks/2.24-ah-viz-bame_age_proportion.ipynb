# %% [markdown]
# # Development and testing for proportions of the prison population, by age group and ethnicity.

# %% [markdown]
# ## Script test

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from src.visualization.people_in_prison import bame_age_proportion

# %%
fig = bame_age_proportion.prepare_chart()
fig

# %% [markdown]
# # Development and testing for child custody and offending chart

# %% [markdown]
# ## Script test

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from src.visualization.people_in_prison import child_custody_offences

# %%
fig = child_custody_offences.prepare_chart()
fig

# %% [markdown]
# # Development and testing for self-harm visualization

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from src.visualization.safety import plotly_assault_rates

# %%
from src.visualization import prt_theme

# %%
prt_theme.pio.templates['prt_template']
# Out:
# layout.Template({
#     'data': {'scatter': [{'line': {'width': 4}, 'marker': {'size': 10}, 'type': 'scatter'}]},
#     'layout': {'colorway': [#A01D28, #499CC9, #F9A237, #6FBA3A, #573D6B],
#                'font': {'color': '#54565B', 'family': 'Helvetica Neue, Arial', 'size': 14},
#                'height': 500,
#                'modebar': {'activecolor': '#A01D28'},
#                'paper_bgcolor': 'rgba(1,1,1,0)',
#                'plot_bgcolor': 'rgba(1,1,1,0)',
#                'showlegend': False,
#                'title': {'font': {'family': 'Helvetica Neue, Arial', 'size': 20}, 'y': 0.94, 'yanchor': 'bottom'},
#                'width': 700,
#                'xaxis': {'showgrid': False, 'tickcolor': '#54565B'}}
# })
